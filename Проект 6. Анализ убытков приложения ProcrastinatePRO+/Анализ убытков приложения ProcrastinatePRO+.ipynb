# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Вводная-часть:" data-toc-modified-id="Вводная-часть:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Вводная часть:</a></span></li><li><span><a href="#Загрузить-данные-и-подготовить-их-к-анализу" data-toc-modified-id="Загрузить-данные-и-подготовить-их-к-анализу-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузить данные и подготовить их к анализу</a></span><ul class="toc-item"><li><span><a href="#Загрузим-данные-о-визитах,-заказах-и-расходах-в-переменные:" data-toc-modified-id="Загрузим-данные-о-визитах,-заказах-и-расходах-в-переменные:-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Загрузим данные о визитах, заказах и расходах в переменные:</a></span></li><li><span><a href="#Приведем-названия-столбцов-к-необходимому-виду:" data-toc-modified-id="Приведем-названия-столбцов-к-необходимому-виду:-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Приведем названия столбцов к необходимому виду:</a></span></li><li><span><a href="#Преобразуем-данные-о-времени:" data-toc-modified-id="Преобразуем-данные-о-времени:-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Преобразуем данные о времени:</a></span></li><li><span><a href="#Рассмотрим-столбец-orders['revenue']:" data-toc-modified-id="Рассмотрим-столбец-orders['revenue']:-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Рассмотрим столбец <code>orders['revenue']</code>:</a></span></li><li><span><a href="#Проверим-файлы-на-наличие-дубликатов-и-пропусков-по-столбцам:" data-toc-modified-id="Проверим-файлы-на-наличие-дубликатов-и-пропусков-по-столбцам:-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Проверим файлы на наличие дубликатов и пропусков по столбцам:</a></span></li><li><span><a href="#Подведем-итог-первой-части-проекта:" data-toc-modified-id="Подведем-итог-первой-части-проекта:-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Подведем итог первой части проекта:</a></span></li></ul></li><li><span><a href="#Задать-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Задать-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Задать функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Создадим-функцию-для-получения-пользовательских-профилей-get_profiles():" data-toc-modified-id="Создадим-функцию-для-получения-пользовательских-профилей-get_profiles():-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создадим функцию для получения пользовательских профилей get_profiles():</a></span></li><li><span><a href="#Создадим-функцию-для-расчёта-коэффициента-удержания-get_retention():" data-toc-modified-id="Создадим-функцию-для-расчёта-коэффициента-удержания-get_retention():-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Создадим функцию для расчёта коэффициента удержания get_retention():</a></span></li><li><span><a href="#Создадим-функцию-для-расчёта-конверсии-get_conversion():" data-toc-modified-id="Создадим-функцию-для-расчёта-конверсии-get_conversion():-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Создадим функцию для расчёта конверсии get_conversion():</a></span></li><li><span><a href="#Создадим-функцию-для-расчёта-LTV---get_ltv():" data-toc-modified-id="Создадим-функцию-для-расчёта-LTV---get_ltv():-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Создадим функцию для расчёта LTV - get_ltv():</a></span></li><li><span><a href="#Напишем-функцию-plot_retention(),-для-построения-графиков" data-toc-modified-id="Напишем-функцию-plot_retention(),-для-построения-графиков-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Напишем функцию plot_retention(), для построения графиков</a></span></li><li><span><a href="#Напишем-для-визуализации-конверсии-—-plot_conversion()" data-toc-modified-id="Напишем-для-визуализации-конверсии-—-plot_conversion()-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Напишем для визуализации конверсии — plot_conversion()</a></span></li><li><span><a href="#Напишем-функцию-для-визуализации-LTV-и-ROI" data-toc-modified-id="Напишем-функцию-для-визуализации-LTV-и-ROI-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Напишем функцию для визуализации LTV и ROI</a></span></li><li><span><a href="#Подведем-итог-второй-части-проекта:" data-toc-modified-id="Подведем-итог-второй-части-проекта:-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Подведем итог второй части проекта:</a></span></li></ul></li><li><span><a href="#Шаг-3.-Проведите-исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Проведите-исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Шаг 3. Проведите исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Получим-профили-пользователей" data-toc-modified-id="Получим-профили-пользователей-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Получим профили пользователей</a></span></li><li><span><a href="#Определим-минимальную-и-максимальную-даты-привлечения-пользователей" data-toc-modified-id="Определим-минимальную-и-максимальную-даты-привлечения-пользователей-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Определим минимальную и максимальную даты привлечения пользователей</a></span></li><li><span><a href="#Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-из-каждой-страны" data-toc-modified-id="Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-из-каждой-страны-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны</a></span></li><li><span><a href="#Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-устройства" data-toc-modified-id="Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-устройства-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства</a></span></li><li><span><a href="#Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-канала-привлечения" data-toc-modified-id="Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-канала-привлечения-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения</a></span></li><li><span><a href="#Подведем-итог-третьей-части-проекта" data-toc-modified-id="Подведем-итог-третьей-части-проекта-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Подведем итог третьей части проекта</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Сколько-денег-было-потрачено-на-маркетинг?" data-toc-modified-id="Сколько-денег-было-потрачено-на-маркетинг?-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Сколько денег было потрачено на маркетинг?</a></span></li><li><span><a href="#Сколько-денег-было-потрачено-всего-от-каждого-источника?" data-toc-modified-id="Сколько-денег-было-потрачено-всего-от-каждого-источника?-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Сколько денег было потрачено всего от каждого источника?</a></span></li><li><span><a href="#Рассчитаем-средний-CAC-на-одного-пользователя-для-всего-проекта--и-для-каждого-источника-трафика" data-toc-modified-id="Рассчитаем-средний-CAC-на-одного-пользователя-для-всего-проекта--и-для-каждого-источника-трафика-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Рассчитаем средний CAC на одного пользователя для всего проекта  и для каждого источника трафика</a></span></li><li><span><a href="#Подведем-итог-четвертой-части-проекта" data-toc-modified-id="Подведем-итог-четвертой-части-проекта-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Подведем итог четвертой части проекта</a></span></li></ul></li><li><span><a href="#Оценить-окупаемость-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оценить-окупаемость-рекламы-для-привлечения-пользователей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Оценить окупаемость рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Проанализируем-общую-окупаемость-рекламы" data-toc-modified-id="Проанализируем-общую-окупаемость-рекламы-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Проанализируем общую окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Рассчитаем-и-визуализируем-LTV-и-ROI,-вызвав-функции-get_ltv()-и-plot_ltv_roi()-без-разбивки-пользователей" data-toc-modified-id="Рассчитаем-и-визуализируем-LTV-и-ROI,-вызвав-функции-get_ltv()-и-plot_ltv_roi()-без-разбивки-пользователей-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Рассчитаем и визуализируем LTV и ROI, вызвав функции get_ltv() и plot_ltv_roi() без разбивки пользователей</a></span></li></ul></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по устройствам</a></span><ul class="toc-item"><li><span><a href="#Посчитаем-конверсию-и-удержание-пользователей-с-разбивкой-по-устройствам" data-toc-modified-id="Посчитаем-конверсию-и-удержание-пользователей-с-разбивкой-по-устройствам-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Посчитаем конверсию и удержание пользователей с разбивкой по устройствам</a></span></li></ul></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по странам</a></span><ul class="toc-item"><li><span><a href="#Посчитаем-конверсию-и-удержание-пользователей-с-разбивкой-по-странам" data-toc-modified-id="Посчитаем-конверсию-и-удержание-пользователей-с-разбивкой-по-странам-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Посчитаем конверсию и удержание пользователей с разбивкой по странам</a></span></li></ul></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по рекламным каналам</a></span><ul class="toc-item"><li><span><a href="#Посчитаем-конверсию-и-удержание-пользователей-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Посчитаем-конверсию-и-удержание-пользователей-с-разбивкой-по-рекламным-каналам-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>Посчитаем конверсию и удержание пользователей с разбивкой по рекламным каналам</a></span></li></ul></li><li><span><a href="#Посчитаем-все-необходимые-экономические-метрики-для-самого-проблемного-рынка-с-разбивкой-по-каналам" data-toc-modified-id="Посчитаем-все-необходимые-экономические-метрики-для-самого-проблемного-рынка-с-разбивкой-по-каналам-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Посчитаем все необходимые экономические метрики для самого проблемного рынка с разбивкой по каналам</a></span></li><li><span><a href="#Подведем-итог-заключительной-части-проекта" data-toc-modified-id="Подведем-итог-заключительной-части-проекта-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Подведем итог заключительной части проекта</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# ## Вводная часть:

# %% [markdown]
# Несколько месяцев назад приложение Procrastinate Pro+ постоянно нес убытки - в привлечение пользователей была вложена куча денег, а толку никакого. Необходимо разобраться в причинах этой ситуации.
#
# Для анализа текущей ситуации имеется лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов. Необходимо изучить, как люди пользуются продуктом, когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.
#
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - рекламные расходы.
#
# Неободимо изучить:
# - откуда приходят пользователи и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов;
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.

# %% [markdown]
# ## Загрузить данные и подготовить их к анализу

# %% [markdown]
# ### Загрузим данные о визитах, заказах и расходах в переменные:

# %% [markdown]
# Откроем необходимые библиотеки:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from datetime import datetime, timedelta # импортируем функции для работы со временем
from matplotlib import pyplot as plt

# %% [markdown]
# Загрузим необходимые данные, выведим их на экран:

# %%
visits = pd.read_csv('/datasets/visits_info_short.csv')
orders = pd.read_csv('/datasets/orders_info_short.csv')
costs = pd.read_csv('/datasets/costs_info_short.csv')

display (visits.head(10))
visits.info()

display (orders.head(10))
orders.info()

display (costs.head(10))
costs.info()
# Out:
#         User Id         Region   Device         Channel        Session Start  \
# 0  981449118918  United States   iPhone         organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone         organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac         organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android          TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac         organic  2019-05-01 03:33:35
# 5   90242400005  United States   iPhone  RocketSuperAds  2019-05-01 07:14:52
# 6   43958116050  United States  Android         organic  2019-05-01 09:03:21
# 7  185365244969  United States   iPhone         organic  2019-05-01 09:37:03
# 8  446013509831  United States   iPhone  RocketSuperAds  2019-05-01 10:26:00
# 9  100970711362  United States      Mac          TipTop  2019-05-01 04:39:53
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# ...

# %% [markdown]
# **После предварительного анализа файлов с целью оптимизации дальнейшего исследования необходимо сделать следующее:**
#
# - привести все названия столбцов к нижнему регистру;
# - установить для названий столбцов «змеиный_регистр», устранив тем самым в них пробелы;
# - преобразовать данные о времени;
# - преобразовать столбец `orders['Revenue']` в тип данных вида int();
# - проверить файлы на наличие дубликатов, в случае их нахождения - удалить

# %% [markdown]
# ### Приведем названия столбцов к необходимому виду:

# %%
# все символы в названиях столбцов сделаем строчными и с «змеиным_регистром»:

visits = visits.rename(columns={'User Id': 'user_id', 'Region': 'region', 'Device': 'device',
                                'Channel': 'channel', 'Session Start': 'session_start',
                                'Session End': 'session_end'}) 

orders = orders.rename(columns={'User Id': 'user_id', 'Event Dt': 'event_dt', 'Revenue': 'revenue'})

costs = costs.rename(columns={'Channel': 'channel'})


print(visits.columns, orders.columns, costs.columns)
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object') Index(['user_id', 'event_dt', 'revenue'], dtype='object') Index(['dt', 'channel', 'costs'], dtype='object')

# %% [markdown]
# ### Преобразуем данные о времени:

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date 

print(visits['session_start'].dtype)
print(visits['session_end'].dtype)
print(orders['event_dt'].dtype)
print(costs['dt'].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]
# datetime64[ns]
# object

# %% [markdown]
# ### Рассмотрим столбец `orders['revenue']`:

# %% [markdown]
# Для начала посмотрим какие значения в себе несет столбец `revenue` перед тем как корректировать значения в нем, иначе можно существенно изменить данные, которые неверно интерпритируют результаты исследования в дальнейшем:

# %%
orders['revenue'].unique()
# Out:
# array([ 4.99,  5.99,  9.99, 49.99, 19.99])

# %% [markdown]
# Получив уникальные значения рассматриваемого столбца выше, необходимо сначала округлить значения в большую сторону, а затем преобразовать данные в тип int():

# %%
orders['revenue'] = np.ceil(orders['revenue'])
orders['revenue'] = orders['revenue'].astype('int')

print(orders['revenue'].unique())
print(orders['revenue'].dtype)
# Out:
# [ 5  6 10 50 20]
# int64

# %% [markdown]
# ### Проверим файлы на наличие дубликатов и пропусков по столбцам:

# %%
print('Количество дубликатов:')
print(visits.duplicated().sum())
print(orders.duplicated().sum())
print(costs.duplicated().sum())
print('Количество пропусков по столбцам:')
print(visits.isna().sum())
print(orders.isna().sum())
print(costs.isna().sum())
# Out:
# Количество дубликатов:
# 0
# 0
# 0
# Количество пропусков по столбцам:
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64
# dt         0
# channel    0
# costs      0
# dtype: int64

# %% [markdown]
# ### Подведем итог первой части проекта:
# - открыли файлы необохдимые для анализа и изучили их содержание;
# - привели названия столбцов к необходимому виду;
# - преобразовали предложенные данные о времени в необходимый вид;
# - преоборазовали данные в столбце `orders['revenue']` в необоходимый вид;
# - проверили файлы на наличие дубликатов и пропусков по столбцам - ничего из этого не было обнаруженно
#
# **Результат проделанной работы: данные готовы для дальнейшего анализа!**

# %% [markdown]
# ## Задать функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# ### Создадим функцию для получения пользовательских профилей get_profiles():

# %% [markdown]
# *Её аргументы:<br>*
# - `sessions` — данные журнала сессий;<br>
# - `orders` — данные о покупках;<br>
# - `ad_costs` — траты на рекламу

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())



    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Создадим функцию для расчёта коэффициента удержания get_retention():

# %% [markdown]
# *Её аргументы:*
# - `profiles` — профили пользователей,
# - `sessions` — данные журнала сессий,
# - `observation_date` — момент анализа,
# - `horizon_days` — горизонт анализа в днях,
# - `ignore_horizon` — опция «игнорировать горизонт анализа», по умолчанию `False`.

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Создадим функцию для расчёта конверсии get_conversion():

# %%
def get_conversion(
    profiles,
    purchases,    # для конверсии заменим аргумент sessions на purchases (англ. «покупки»)
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу:
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # добавляем размеры когорт к треугольной таблице
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа:
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Создадим функцию для расчёта LTV - get_ltv():

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Напишем функцию plot_retention(), для построения графиков

# %% [markdown]
# *Неободимые графики для дальнейшего анализа:*
# - кривые удержания для платящих пользователей;
# - кривые удержания для неплатящих;
# - динамику удержания для платящих пользователей;
# - динамику удержания для неплатящих

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Напишем для визуализации конверсии — plot_conversion()

# %% [markdown]
# Результатом её вызова будут два графика: кривые и динамика

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Напишем функцию для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Подведем итог второй части проекта:
# - задали функции для расчета LTV, ROI, удержания и конверсии;
# - задали функции для визуализации необходимых метрик
#
# **Результат проделанной работы:** *всё готово для продолжения исследовательского анализа данных!*

# %% [markdown]
# ## Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# ### Получим профили пользователей

# %% [markdown]
# Для этого вызовем функцию get_profiles(), передав ей данные о посещениях, покупках и тратах на рекламу:

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head(10)
# Out:
#     user_id            first_ts       channel   device         region  \
# 0    599326 2019-05-07 20:58:57      FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:07      FaceBoom   iPhone  United States
# 2   6085896 2019-10-01 09:58:33       organic   iPhone         France
# 3  22593348 2019-08-22 21:35:48    AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:44       YRabbit   iPhone  United States
# 5  34186288 2019-05-09 17:29:23       organic  Android  United States
# 6  38448301 2019-08-16 11:56:00       organic  Android  United States
# 7  46006712 2019-06-30 03:46:29    AdNonSense  Android         France
# 8  58263264 2019-05-11 19:18:43      FaceBoom   iPhone  United States
# 9  59835779 2019-05-11 21:13:47  MediaTornado   iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# ...

# %% [markdown]
# ### Определим минимальную и максимальную даты привлечения пользователей

# %%
min_analysis_date = profiles['dt'].min()
max_analysis_date = profiles['dt'].max()

print(min_analysis_date, max_analysis_date)
# Out:
# 2019-05-01 2019-10-27

# %% [markdown]
# ### Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны

# %%
dt1 = profiles.groupby('region').agg({'user_id': 'nunique', 'payer': 'mean'}).sort_values(by='user_id', ascending=False)

dt1['ratio_user'] = dt1['user_id'] / dt1['user_id'].sum() # Определили долю пользователей с каждой страны
dt1 = dt1.reindex(columns=['user_id','ratio_user','payer']) # Поменяли очередность столбцов


# Так как столбец "payer" несет в себе булевые значения, то определив для него среднее значение мы нашли и долю
# платящих клиентов. Благодаря этому, стало возможно опрередить число платящих клиентов для каждой страны:

dt1['buyer'] = dt1['user_id'] * dt1['payer'] # определим количество платящих пользователей из каждой страны
dt1['ratio_buyer'] = dt1['buyer'] / dt1['buyer'].sum() # определим долю платящих пользователей каждой страны 
# от общего количества платящих клиентов

dt1
# Out:
#                user_id  ratio_user     payer   buyer  ratio_buyer
# region
# United States   100002    0.666644  0.069019  6902.0     0.777165
# UK               17575    0.117160  0.039829   700.0     0.078820
# France           17450    0.116327  0.037994   663.0     0.074654
# Germany          14981    0.099868  0.041119   616.0     0.069362

# %% [markdown]
# <br>*Визализируем полученную выше таблицу при помощи построения гистограммы:*

# %%
dt1.plot(y='ratio_buyer', kind='pie', normalize=True, figsize=(10,10), legend=True, fontsize=15)
plt.legend(bbox_to_anchor=(1,0.9))
plt.axis('off')
plt.title('Гистограмма, отражающая долю платящих пользователей из каждой страны от их общего количества', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Гистограмма, отражающая долю платящих пользователей из каждой страны от их общего количества')

# %% [markdown]
# ### Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства

# %%
dt2 = profiles.groupby('device').agg({'user_id': 'nunique', 'payer': 'mean'}).sort_values(by='user_id', ascending=False)

dt2['ratio_user'] = dt2['user_id'] / dt2['user_id'].sum()
dt2 = dt2.reindex(columns=['user_id','ratio_user','payer'])

dt2['buyer'] = dt2['user_id'] * dt2['payer'] # определим количество платящих пользователей, использующее определенное устр-во
dt2['ratio_buyer'] = dt2['buyer'] / dt2['buyer'].sum() # определим долю платящих пользователей каждой страны от их общего количества
dt2
# Out:
#          user_id  ratio_user     payer   buyer  ratio_buyer
# device
# iPhone     54479    0.363174  0.062079  3382.0     0.380813
# Android    35032    0.233534  0.058518  2050.0     0.230830
# PC         30455    0.203023  0.050468  1537.0     0.173066
# Mac        30042    0.200269  0.063644  1912.0     0.215291

# %% [markdown]
# *Визализируем полученную выше таблицу при помощи построения гистограммы:*

# %%
dt2.plot(y='ratio_buyer', kind='pie', normalize=True, figsize=(10,10), legend=True, fontsize=15)
plt.legend(bbox_to_anchor=(1,0.9))
plt.axis('off')
plt.title('Гистограмма,отражающая долю платящих пользователей с определенных устройств от их общего количества', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Гистограмма,отражающая долю платящих пользователей с определенных устройств от их общего количества')

# %% [markdown]
# ### Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения

# %%
dt3 = profiles.groupby('channel').agg({'user_id': 'nunique', 'payer': 'mean'}).sort_values(by='user_id', ascending=False)

dt3['ratio_user'] = dt3['user_id'] / dt3['user_id'].sum()
dt3 = dt3.reindex(columns=['user_id','ratio_user','payer'])

dt3['buyer'] = dt3['user_id'] * dt3['payer']
dt3['ratio_buyer'] = dt3['buyer'] / dt3['buyer'].sum()
dt3
# Out:
#                     user_id  ratio_user     payer   buyer  ratio_buyer
# channel
# organic               56439    0.376240  0.020553  1160.0     0.130616
# FaceBoom              29144    0.194283  0.122049  3557.0     0.400518
# TipTop                19561    0.130400  0.096007  1878.0     0.211463
# OppleCreativeMedia     8605    0.057364  0.027077   233.0     0.026236
# LeapBob                8553    0.057017  0.030633   262.0     0.029501
# WahooNetBanner         8553    0.057017  0.052964   453.0     0.051008
# RocketSuperAds         4448    0.029652  0.079137   352.0     0.039635
# MediaTornado           4364    0.029092  0.035747   156.0     0.017566
# YRabbit                4312    0.028745  0.038265   165.0     0.018579
# AdNonSense             3880    0.025865  0.113402   440.0     0.049544
# lambdaMediaAds         2149    0.014326  0.104700   225.0     0.025335

# %% [markdown]
# *Подготовим таблицу для дальнейшей визуализации при помощи гистограммы:*

# %%
# Создадим дата-фрейм с разбивкой пользователей по каналам:
dt31 = dt3[['user_id', 'ratio_user']]
dt31 = dt31.head(7)
dt31.loc['другое'] = ['-', 1-dt31['ratio_user'].sum()]

display(dt31)

# Создадим дата-фрейм с разбивкой платящих пользователей по каналам:
dt32 = dt3[['buyer', 'ratio_buyer']]
dt32 = dt32.head(7)
dt32.loc['другое'] = ['-', 1-dt32['ratio_buyer'].sum()]

display(dt32)
# Out:
#                    user_id  ratio_user
# channel
# organic              56439    0.376240
# FaceBoom             29144    0.194283
# TipTop               19561    0.130400
# OppleCreativeMedia    8605    0.057364
# LeapBob               8553    0.057017
# WahooNetBanner        8553    0.057017
# RocketSuperAds        4448    0.029652
# другое                   -    0.098028
#                      buyer  ratio_buyer
# channel
# organic             1160.0     0.130616
# FaceBoom            3557.0     0.400518
# TipTop              1878.0     0.211463
# OppleCreativeMedia   233.0     0.026236
# LeapBob              262.0     0.029501
# WahooNetBanner       453.0     0.051008
# RocketSuperAds       352.0     0.039635
# другое                   -     0.111024

# %% [markdown]
# *Визализируем полученную выше таблицу при помощи построения графика:*

# %%
dt31.plot(y='ratio_user', kind='pie', normalize=True, figsize=(11,11), startangle=246, fontsize=15)
plt.legend(bbox_to_anchor=(1.5,0.9))
plt.axis('off')
plt.title('Гистограмма, отражающая долю всех пользователей от общего количества с разбивкой по рекламным каналам'
          , fontsize=15)


dt32.plot(y='ratio_buyer', kind='pie', normalize=True, figsize=(11,11), startangle=260, fontsize=15)
plt.legend(bbox_to_anchor=(1.5,0.9))
plt.axis('off')
plt.title('Гистограмма, отражающая долю платящих пользователей от общего их количества с разбивкой по рекламным каналам'
          , fontsize=15)
# Out:
# Text(0.5, 1.0, 'Гистограмма, отражающая долю платящих пользователей от общего их количества с разбивкой по рекламным каналам')

# %% [markdown]
# ### Подведем итог третьей части проекта
# <br>
#
# **В ходе данной части проекта удалось сделать:**
# - Получили профили пользователей;
# - Определили минимальную и максимальную дату привличения пользователей. Это понадобится в дальнейшем для корректной работы функций, написанных ранее;
# - Построили таблицу отражающую количество пользователей и их доли от общего количества с разбивкой по странам, устройствам и рекламным каналам
# - Все вышеописанные таблицы удалось визуализировать при помощи круговых гистограмм
#
# **В ходе данной части проекта удалось выяснить:**
# 1. Основное число пользователей как всех (66,7%), так и платящих (78,3%) используют наше приложение из США;
# 2. В наше устройство входят в основном со смартфонов: их доля от всех пользователей - 60%, платящих пользователей от их общего количества - 61,3%;
# 3. Чаще всего заходят в наше приложение со смартфонов IPhone (36,3% и 38,4%) и с Android (23,3% и 22,9%);
# 4. В целом можно с уверенностью сказать, что наше приложение оптимизировано под каждое современное устройство;
# 5. В основном пользователи к нам идут с каналов organic (37,6% и 13,6%), FaceBoom (19,4% и 40,0%), TipTop (13,0% и 21,1%), OppleCreativeMedia (5,7% и 2,6%);
# 6. Если судить о том, что чем выше доля платящих клиентов от их общего количества тем ближе эти пользователи к нашей основной целевой аудитории, то здесь выделяются каналы: FaceBoom (40%) и TipTop (21%)

# %% [markdown]
# ## Маркетинг
#
# Выясним:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# ### Сколько денег было потрачено на маркетинг?

# %%
sum_cost = costs['costs'].sum()

sum_cost
# Out:
# 105497.30000000002

# %% [markdown]
# ### Сколько денег было потрачено всего от каждого источника?

# %%
dt4 = costs.groupby(['channel'])[['costs']].sum().sort_values(ascending=False, by='costs')
dt4 = dt4.merge(dt4, on=['channel', 'costs'], how='left').reset_index()
dt4['ratio'] = dt4['costs'] / dt4['costs'].sum()
display(dt4)


fig, ax = plt.subplots()
x = dt4['channel'].tolist()
y = dt4['costs'].tolist()
plt.bar(x, y)
fig.set_figwidth(70)    #  ширина Figure
fig.set_figheight(45)    #  высота Figure
plt.xlabel('Наименование каналов', fontsize=56)
plt.ylabel('Стоимость рекламы', fontsize=56)
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(36)
plt.show()
# Out:
#               channel     costs     ratio
# 0              TipTop  54751.30  0.518983
# 1            FaceBoom  32445.60  0.307549
# 2      WahooNetBanner   5151.00  0.048826
# 3          AdNonSense   3911.25  0.037074
# 4  OppleCreativeMedia   2151.25  0.020392
# 5      RocketSuperAds   1833.00  0.017375
# 6             LeapBob   1797.60  0.017039
# 7      lambdaMediaAds   1557.60  0.014764
# 8        MediaTornado    954.48  0.009047
# 9             YRabbit    944.22  0.008950

# %% [markdown]
# <br>**Визуализируем изменения метрик во времени (по дням, месяцам):**

# %%
costs['dt']  = costs['dt'].astype('datetime64[W]').dt.date
costs['month']  = costs['dt'].astype('datetime64[M]').dt.month

costs.pivot_table(index=['dt'], values='costs', columns='channel', aggfunc='sum').plot.area(figsize=(16,8))
plt.title('Изменение стоимости рекламы по дням с разбивкой по рекламным каналам')
costs.pivot_table(index=['month'], values='costs', columns='channel', aggfunc='sum').plot.area(figsize=(16,8))
plt.title('Изменение стоимости рекламы по месяцам с разбивкой по рекламным каналам')
# Out:
# Text(0.5, 1.0, 'Изменение стоимости рекламы по месяцам с разбивкой по рекламным каналам')

# %% [markdown]
# ###  Рассчитаем средний CAC на одного пользователя для всего проекта  и для каждого источника трафика

# %% [markdown]
# *Перед тем как начать расчет среднего значения показателя САС, уберем из дата-сета с профилями неплатящих пользователей:*

# %%
profiles = profiles.query('channel != "organic"') # удалим органический трафик

display(profiles)
profiles['payer'].mean()
# Out:
#              user_id            first_ts       channel   device  \
# 0             599326 2019-05-07 20:58:57      FaceBoom      Mac
# 1            4919697 2019-07-09 12:46:07      FaceBoom   iPhone
# 3           22593348 2019-08-22 21:35:48    AdNonSense       PC
# 4           31989216 2019-10-02 00:07:44       YRabbit   iPhone
# 7           46006712 2019-06-30 03:46:29    AdNonSense  Android
# ...              ...                 ...           ...      ...
# 149999  999942424543 2019-05-24 21:03:26        TipTop   iPhone
# 150001  999949280903 2019-08-12 06:47:27      FaceBoom      Mac
# 150003  999956196527 2019-09-28 08:33:02        TipTop   iPhone
# 150005  999976332130 2019-07-23 02:57:06        TipTop   iPhone
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado       PC
#
#                region          dt      month  payer  acquisition_cost
# 0       United States  2019-05-07 2019-05-01   True          1.088172
# ...

# %% [markdown]
# <br> *Определим среднее значение САС по всем каналам:*

# %%
print(profiles['acquisition_cost'].mean())
# Out:
# 1.1274813239427588

# %% [markdown]
# <br> *Определим среднее значение САС с разбивкой по каналам:*

# %%
profiles1 = profiles.groupby('channel')[['acquisition_cost']].mean().sort_values(ascending=False, by='acquisition_cost')
profiles1 = profiles1.merge(profiles1, on=['channel', 'acquisition_cost'], how='left').reset_index()
display(profiles1)

fig, ax = plt.subplots()
x = profiles1['channel'].tolist()
y = profiles1['acquisition_cost'].tolist()

plt.bar(x, y)
x_min = np.linspace(-10, 1.17, 10)
fig.set_figwidth(70)
fig.set_figheight(45)
plt.title('Среднее значение САС с разбивкой по каналам', fontsize=86)
plt.xlabel('Наименование каналов', fontsize=56)
plt.ylabel('Средняя стоимость привличения одного пользователя', fontsize=56)
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
	label.set_fontsize(36)
plt.show()
# Out:
#               channel  acquisition_cost
# 0              TipTop          2.799003
# 1            FaceBoom          1.113286
# 2          AdNonSense          1.008054
# 3      lambdaMediaAds          0.724802
# 4      WahooNetBanner          0.602245
# 5      RocketSuperAds          0.412095
# 6  OppleCreativeMedia          0.250000
# 7             YRabbit          0.218975
# 8        MediaTornado          0.218717
# 9             LeapBob          0.210172

# %% [markdown]
# **Вывод по полученным данным:** единственный канал, который преодалел средний CAC на одного пользователя для всего проекта: это канал TipTop - у него значение САС почти в два раза выше чем в среднем по всем каналам. Но все же пока рано давать какую-нибудь оценку этому и другим каналам, не оценив показатель окупаемости затрат

# %% [markdown]
# ### Подведем итог четвертой части проекта
#
# <br>**В ходе данной части проекта удалось сделать:**
# - Определили сколько денег было потрачено на маркетинг;
# - Определили сколько денег было потрачено всего от каждого источника;
# - Визуализировали изменения метрик во времени (по дням, месяцам)
#
# **В ходе данной части проекта удалось выяснить:**
# 1. Денег было потрачено на маркетинг за рассматриваемый период - 105497.3;
# 2. Больше всего былло потраченно на рекламный канал TipTop и FaceBoom. Процент на оплату их услуг от всего рекламного бюджета составляет - 51,9% и 33,8%;
# 3. Тенденцию по увеличению бюджета на рекламу перехватывают те же самые ранее рассмотренные рекламные каналы. Далее выясним оправдывают ли наши вложения в их деятельность;
# 4. Единственный канал, который преодалел средний CAC на одного пользователя для всего проекта: это канал TipTop - у него значение САС почти в два раза выше чем в среднем по всем каналам

# %% [markdown]
# ## Оценить окупаемость рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализируем общую окупаемость рекламы;
# - Проанализируем окупаемость рекламы с разбивкой по устройствам;
# - Проанализируем окупаемость рекламы с разбивкой по странам;
# - Проанализируем окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишем проблемы, которые вы обнаружили и ответим на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучите конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Основываясь на полученных данных, определим возможные причины обнаруженных проблем и сформируем рекомендации для рекламного отдела

# %% [markdown]
# ### Проанализируем общую окупаемость рекламы

# %% [markdown]
# *Для начала зададим первоначальные условия:*

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа 
horizon_days = 14  # горизонт анализа (срок, когда должна наступить окупаемость рекламы)

# %% [markdown]
# #### Рассчитаем и визуализируем LTV и ROI, вызвав функции get_ltv() и plot_ltv_roi() без разбивки пользователей

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)


# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# **По графикам можно сделать такие выводы:**
# - Реклама не окупается за выбранный промежуток времени (14 дней). Значение ROI на четвертом графике не пересекает уровень окупаемости, но тенденция к этому есть - нужно определить, что мешает этому в ходе дальнейших исследований;
# - CAC стабильбно увеличивается. Значит, рекламный бюджет увеличивается и, возможно, в дальнейшем ROI перейдет уровень окупаемости при сохранении тенденции при прочих равных условиях;
# - На LTV влияет сезонный фактор, но и этот показатель достаточно стабилен. Значит, дело не в ухудшении качества пользователей;
# - С мая этого года затраты на привиличение полтьзователей стабильно увеличивались пока не вышли на плато к сентябрю месяца. Возможно, стоит что-то улучшить в плане привлечении или удержании клиентов, так как с июля месяца начинается неокупаемость инвестиций
#
#
# <br>**Чтобы разобраться в причинах, почему реклама до сих пор не окупается, пройдём по всем доступным характеристикам пользователей — стране, устройству посещения и рекламным каналам**

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по устройствам

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['device']
)


# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Вот что говорят графики:
# - Аутсайдер по окупаемости - это пользователи IPhone и Mac, хоть на них тратится бюджет рекламы значительно больше остальных;
# - Единственное устройство с которого окупается реклама -  РС при минимальной стоимости привличения пользователей, относительно других. Также стоит учесть, что затраты на привличении этих пользователей почти всегда стабилно по времени, поэтому можно сделать предположение о том, что пользователи РС намного раньше познакомились с нашим приложением, чем пользователи с другими устройствами, либо реклама лучше работает на них, или наше приложении лучше всего оптимизированно под данный вид устройств;
# - Реклама не окупается и у пользователей Android, но здесь ситуация чуть получше чем у пользователей IPhone и Mac. Возможно, в скором времени есть шанс окупить затраты при сохранении тенденции увеличения расходов на их раскрутку при прочих равных условиях;
# - Явных выводов о том, почему не окупается реклама при сохранении тенденции на увеличение на это бюджета нет, судя по разбивке клиентов по типу используемого ими устройства. Необходимо продолжить поиск корневой проблемы. Определим конверсию и удержание пользователей с разбивкой по используемым устройствам. Возможно, это даст разъяснения не окупаемости пользователей IPhone и Mac

# %% [markdown]
# #### Посчитаем конверсию и удержание пользователей с разбивкой по устройствам

# %%
# смотрим конверсию с разбивкой по устройствам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['device']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Судя по графикам, все пользователи конвертируются очень хорошо, причём постоянно

# %%
# смотрим удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
profiles, visits, observation_date, horizon_days, dimensions=['device']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Выводы по графикам плачевны: низкое удержание клиентов. При высокой конверсии наше приложение не способно в дальнейшем ничем заинтересовать пользователя. Нет явных лидеров или аутсайдеров по разбивке пользователей на устройства, нужно продолжать поиски всех проблем из-за чего реклама не окупается

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по странам

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['region']
)


# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Возможно, здесь и кроется проблема - клиенты из США сильно выбиваются относительно других. Ранее мы выяснили, что больше всего пользователей нашего приложения из США (в т.ч. платящих). Даже не смотря на это, а также, что на них тратится в разы больше сил и средств для привличения (судя по графику №3), в целом у пользователей из США значение ROI примерно в два раза ниже чем у пользователей из других стран
#
# Возможно, рынок США новый для приложения Procrastinate Pro+, поэтому для него сейчас идет период "раскачки" в этой стране. В любом случае далее в ходе дальнейшего исследования необходимо узнать есть ли причина низкой окупаемости пользователей из США в том, что у приложения в этой стране низкая конверсия или низкое удержание

# %% [markdown]
# #### Посчитаем конверсию и удержание пользователей с разбивкой по странам

# %%
# смотрим конверсию с разбивкой по странам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['region']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# <br>*Судя по графикам, пользователи из США конвертируются очень хорошо, причём постоянно и в два раза выше чем в других странах. Видимо, дело в удержании. Вызовем функции get_retention() и plot_retention(), чтобы рассчитать и отразить на графиках этот показатель*
# <br><br>

# %%
# смотрим удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
profiles, visits, observation_date, horizon_days, dimensions=['region']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# <br>*Проблема ясна: проблема в удержании клиентов. Хоть пользователи из США более ощутимо выделяются по слабому показателю удержания, но такая же проблема существует в целом у всех пользователей нашего приложения*
#
# Судя по тому, что конверсия у пользователей стабильно высокая, а динамика удержания падает, это говорит о том, что скорее всего пользователи пользуются нашим приложением исключительно для какой-то одной конкретной непродолжительной по времени цели, а затем, получив это - в приложение больше не возвращаются
# <br>

# %% [markdown]
# Регион США является сильно проблемным, но при этом очень перспективным. Определим более детальную проблему не окупаемости, разбив пользователей из США на используемые ими устройства и каналам привличения

# %%
usa = profiles[profiles['region'] == 'United States'] # создадим датафрейм, где страна перехода - США
display(usa['channel'].value_counts(normalize=True))
display(usa['device'].value_counts(normalize=True))
# Out:
# FaceBoom          0.471365
# TipTop            0.316373
# RocketSuperAds    0.071940
# MediaTornado      0.070582
# YRabbit           0.069741
# Name: channel, dtype: float64
# iPhone     0.445551
# Mac        0.249462
# Android    0.201135
# PC         0.103851
# Name: device, dtype: float64

# %% [markdown]
# В получившихся показателях есть закономерность - пользователи из США (которые являются проблемными), пользуются устройствами с низкой окупаемостью: iPhone и Мас (примерно 70%от всех пользователей из США), а в привлечении пользователей участвуют самые затратные каналы, судя по показателю САС (см.п. 5.3). Выресовывается проблемная каста пользователей. Далее определимся с каналами, чтобы выявить самые неудачные вложения

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по рекламным каналам

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['channel']
)


# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - Каналы фавориты - YRabbit, MediaTornado, lambdaMediaAds, RocketSuperAds, OppleCreativeMedia, LeapBob и WahooNetBanner. У этих каналов динамика стоимости привличения пользователей стабильна, а значение ROI выше уровеня окупаемости, т.е. пользователи, пришедшие с этих каналов, вносят больше чем на них потратили для привличения
# - Каналы аутсайдеры - AdNonSense, FaceBoom и TipTop - приглашеные ими пользователи не окупили вложенную на них рекламу. Необходимо определить, кто эти пользователи с разбивкой на страны и используемые ими устройства, чтобы понять какие нужно предпринять дальнейшие шаги для этих каналов и понять причину их низких показателей

# %%
adnonsense = visits[visits['channel'] == 'AdNonSense'] # создадим датафрейм, где источник перехода - "AdNonSense"
display(adnonsense['region'].value_counts())
display(adnonsense['device'].value_counts())
print()

faceboom = visits[visits['channel'] == 'FaceBoom'] # создадим датафрейм, где источник перехода - "FaceBoom"
display(faceboom['region'].value_counts())
display(faceboom['device'].value_counts())
print()

tiptop = visits[visits['channel'] == 'TipTop'] # создадим датафрейм, где источник перехода - "TipTop"
display(tiptop['region'].value_counts())
display(tiptop['device'].value_counts())
# Out:
# France     2381
# UK         2327
# Germany    2183
# Name: region, dtype: int64
# PC         2760
# Android    1993
# iPhone     1430
# Mac         708
# Name: device, dtype: int64
# United States    49022
# Name: region, dtype: int64
# iPhone     21866
# Mac        12262
# Android     9793
# PC          5101
# Name: device, dtype: int64
# United States    54794
# Name: region, dtype: int64
# iPhone     24608
# Mac        13153
# Android    11424
# PC          5609
# Name: device, dtype: int64

# %% [markdown]
# - Каналы "FaceBoom" и "TipTop" нацелены на "проблемных" клиентов - пользователи у них приходят в наше приложение из США с устройства продукции "Apple" (iPhone, Mac). Стоит все-таки уточнить у наших маркетологов, почему это проблемные пользователи для нас - скорее всего, как говорилось ранее, с такими клиентами наша компания работает недавно, поэтому бюджет на рекламу на них тратится существенно выше чем на привличение других пользователей. В любом случае необходимо за каналами "FaceBoom" и "TipTop" продолжить наблюдение;
#
#
# - Много вопросов про канал "AdNonSense" - судя по разбивке клиентов по странам и устройствам, этот канал работает с нашей основной целевой аудиторией. Необходимо переговорить с представителем данного канала для разъяснения ситуации почему пользователей, которые они приглашают к нам в приложение, не окупают вложенные на них средства, либо расторгнуть с ними контракт в случае ненахождения компромиссов

# %% [markdown]
# Хоть мы и поняли, что основная проблема слабой окупаемости нашей рекламы - это низкое удержание пользователей, все же определим для рекламных каналов конверсию и удержание, чтобы более ясно понять с какими каналами мы работаем:

# %% [markdown]
# #### Посчитаем конверсию и удержание пользователей с разбивкой по рекламным каналам

# %%
# смотрим конверсию с разбивкой по рекламным каналам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['channel']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# смотрим удержание с разбивкой по рекламным каналам

retention_raw, retention_grouped, retention_history = get_retention(
profiles, visits, observation_date, horizon_days, dimensions=['channel']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# <br>Как и говорилось - основная проблема в не окупаемости рекламы - слабое удержание пользователей (в т.ч. платящих)<br>
# <br>Выводы по каналам:
# - Определились аутсайдеры по рекламным каналам - AdNonSense и FaceBoom. У этих каналов все интересующие нас показатели ниже остальных каналов. Необходимо обсудить, почему приглашенные через их каналы пользователи, не окупают вложенную на них рекламу;
# - В целом явных фаваритов по каналам нет - примерно все на одинаковом высоком уровне по привличению клиентов. Почему пользователи уходят от нас - вопрос к качеству приглашаемых пользователей, либо это наша недоработка по причине плохого, не интуитивного интерфейса, слабого функционала либо в связи с нарастанием амбиций наших конкурентов
# <br><br>

# %% [markdown]
# ### Посчитаем все необходимые экономические метрики для самого проблемного рынка с разбивкой по каналам

# %% [markdown]
# Так как мы уже определились, что проблемный рынок - это рынок США (где основное устройство пользования - продукция Apple, которое тоже является достаточно проблемным), определим для него перспективные каналы:

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    usa, orders, observation_date, horizon_days, dimensions=['channel']
)
# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# смотрим конверсию с разбивкой по рекламным каналам
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    usa, orders, observation_date, horizon_days, dimensions=['channel']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days) 

# смотрим удержание с разбивкой по рекламным каналам
retention_raw, retention_grouped, retention_history = get_retention(
usa, visits, observation_date, horizon_days, dimensions=['channel']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Вывод по полученным данным:** Опыт работы с проблемным рынком  нужно перенять, судя по графикам, у канала RocketSuperAds и чуть в меньшей степени у YRabbit и Media Tornado. У них приемлемое значение конверсии при затратах гораздо меньшних на привличение клиентов чем у лидеров антирейтинга - TipTop и FaceBoom.
#
# Перспективные каналы мы определили с целью передать другим каналам их опыт и/или возможно даже выделить им больший бюджет на дальнейшую реализацию их деятельности

# %% [markdown]
# ### Подведем итог заключительной части проекта
#
# <br>**В ходе данной части проекта удалось сделать:**
# - Проанализировали общую окупаемость рекламы и с разбивкой по странам, устройствам и рекламным каналам;
# - Рассчитали и визуализировали значения LTV и ROI;
# - Для дополнительного анализа рекламы с разбивкой по странам и устройствам также посчитали и визуализировали конверсию и удержание
#
# **В ходе данной части проекта удалось выяснить:**<br><br>
# *1. При анализе общей окупаемости рекламы:*
#  - Реклама не окупается за выбранный промежуток времени (14 дней). Значение ROI не пересекает уровень окупаемости, но тенденция к этому есть;
#  - CAC стабильбно увеличивается. Значит, возможно, в дальнейшем ROI перейдет уровень окупаемости при сохранении тенденции по увеличнию финансирования рекламы при прочих равных условиях;
#  - На LTV влияет сезонный фактор, но и этот показатель достаточно стабилен. Значит, дело не в ухудшении качества пользователей;
#  - С мая этого года затраты на привиличение полтьзователей стабильно увеличивались пока не вышли на плато к сентябрю месяца. Возможно, стоит что-то улучшить в плане привлечении или удержании клиентов, так как с сентября месяца начинается неокупаемость инвестиций;
#  - Низкое значение удержания пользователей, в т.ч. платящих - основная проблема почему реклама не окупается при достаточно стабильно высоком значении конверации
#
# *2. При анализе окупаемости рекламы с разбивкой по устройствам:*
#  - Аутсайдер по окупаемости - это пользователи IPhone и Mac, хоть на них тратится бюджет рекламы значительно больше остальных;
#  - Реклама не окупается и у пользователей Android, но здесь ситуация чуть получше чем у пользователей IPhone и Mac. Возможно, в скором времени есть шанс окупить затраты при сохранении тенденции увеличения расходов на их раскрутку при прочих равных условиях;
#  - Реклама окупается у пользователей РС при минимальной стоимости привличения пользователей, относительно других. Также затраты на привличении пользователей почти всегда стабильны по времени, поэтому можно сделать предположение о том, что пользователи РС намного раньше познакомились с нашим приложением, чем пользователи с другими устройствами, либо реклама лучше работает на ПК-пользователях;
#  - Явных выводов о том, почему не окупается реклама при сохранении тенденции на увеличение на это бюджета нет, судя по разбивке клиентов по типу используемого ими устройства
#
# *3. При анализе окупаемости рекламы с разбивкой по странам:*
#  - Клиенты из США сильно выбиваются относительно других. Не смотря на то, что больше всего пользователей нашего приложения из США (в т.ч. платящих), а также, что на них тратится в разы больше сил и средств для привличения, в целом у пользователей из США значение ROI примерно в два раза ниже чем у других;
#  - С рынком США работают самые дорогостоящие для нас каналы - FaceBoom и TipTop, которые в сумме охватывают около 80% всего рынка США, при этом работа которых не приносит нам прибыль;
#  - Возможно, также, что рынок США новый для нашего приложения, поэтому для него сейчас идет период "раскачки" в этой стране
#
# *4. При анализе окупаемости рекламы с разбивкой по рекламным каналам:*
#  - Каналы фавориты - YRabbit, MediaTornado, lambdaMediaAds, RocketSuperAds, OppleCreativeMedia, LeapBob и WahooNetBanner. У этих каналов динамика стоимости привличения пользователей стабильна, а значение ROI выше уровеня окупаемости, т.е. пользователи, пришедшие с этих каналов, вносят больше чем на них потратили для привличения;
#  - Каналы аутсайдеры - AdNonSense, FaceBoom и TipTop - приглашенные ими пользователи не окупили вложенную на них рекламу;
#  - Главные аутсайдеры по рекламным каналам -  AdNonSense и FaceBoom все интересующие нас показатели ниже остальных каналов. Необходимо обсудить, почему приглашенные через их каналы пользователи, не окупают вложенную на них рекламу;
#  - Опыт работы с проблемным рынком (США, устройство: Мас и IPhone) нужно перенять у канала RocketSuperAds и чуть в меньшей степени у YRabbit и Media Tornado. У них приемлемое значение конверсии при затратах гораздо меньшних на привличение клиентов чем у лидеров антирейтинга - TipTop и FaceBoom

# %% [markdown]
# ## Выводы

# %% [markdown]
# **Основные причины почему реклама не окупается:**
# - Главная проблема - низкое удержание пользователей, в т.ч. платящих пользователей;
# - Из-за слабого удержания пользователей нельзя встроить в приложение рекламу, чтобы можно было окупить затраты на раскрутку - есть высокий шанс, что это еще сильнее понизит удержание пользователей;
# - Рынок США слишком крупный и перспективный, но при этом на его раскрутку тратится много средств. Возможно, в дальнейшем затраты на него окупятся, если в т.ч. поработать с такими каналами как FaceBoom, Organic и TipTop, которые являются основными каналами для раскрутки нашего приложения в США и которые показывают одни из самых слабых экономических показателей;
# - Так как пользователи из США в оснвном пользуются продукцией Apple (70%), то по этим устройствам точно такие же размышления и рекомендации как и в предыдущем пункте;
# - Основываясь на высоком значении затрачиваемых средств и низкой окупаемости у каналов TipTop и FaceBoom делается вывод о том, что количество денежных средств выплачиваются каналам, отталкиваясь в первую очередь от количества приглашенных пользователей. Из-за этого качество пользователей низкое и как следствие их удержание со временем падает. Поэтому стоит пересмотреть договоры на оказание услуг рекламных каналов, чтобы их денежное вознаграждение зависило также от степени удержания пользователей;
# - Опыт работы с проблемным рынком (страна: США, устройство: Мас и IPhone) нужно перенять у канала RocketSuperAds и чуть в меньшей степени у YRabbit и Media Tornado. У них приемлемое значение конверсии и окупаемости при затратах гораздо меньшних на привличение клиентов чем у лидеров антирейтинга - AdNonSense и FaceBoom
# -  Перспективные каналы, про которые было сказано выше, мы определили с целью передать другим каналам их опыт работы с проблемным рынком, а также возможно выделить им больший бюджет на дальнейшую реализацию их деятельности
#
# **Если говорить дальше о предполажениях, почему реклама не окупается, то стоит проверить следующие гипотезы:**
# - Появился ли конкурент со схожей продукцией, из-за которого у нас съезжает показатель удержания пользователей со временем;
# - Возможно ли что-то оптимизировать в нашем приложении (скорость загрузки, удобность интерфейса и др.), либо добавить новые функции;
# - Возможно ли уменьшить стоимость подписки или продаваемых вещей в приложении тем самым увеличив количество платящих пользователей;
# - Платить рекламным каналам не за приглашенного пользователя, а за пользователя, который пользовался нашим приложением какое-то опрделенное время. Это даст сильный талчок нашим партнерам, чтобы они начали выискивать нашу основную целевую аудиторию;
# - Работать с обратной связью пользователей с целью постоянного поиска оптимизации нашего приложения, а также повышения конкурентоспособности
